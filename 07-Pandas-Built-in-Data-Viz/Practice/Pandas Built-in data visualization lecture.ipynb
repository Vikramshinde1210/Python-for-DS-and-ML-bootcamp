# %%
import os

# %%
os.chdir(r'E:\Data science practice\07-Pandas-Built-in-Data-Viz')

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
# setting index to 0th column
df1 = pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# it is calling the matplotlib underhood
df1['A'].hist()

# %%
# it is also using seaborn
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist')

# %%
df1['A'].plot.hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.scatter('a','d')

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist()

# %%
df1.plot.line('A','B')

# %%
df1.plot.scatter(x='A',y='B',c='D',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100,cmap='coolwarm')
# Out:
# C:\Users\vicky\anaconda3\lib\site-packages\matplotlib\collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# box plot

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['A','B'])

# %%
df
# Out:
#             A         B
# 0   -1.352229  0.617966
# 1   -2.461567 -0.182835
# 2    0.176642  1.397460
# 3    0.178470 -1.597746
# 4    0.877081  0.571073
# ..        ...       ...
# 995  1.420823  0.421257
# 996 -0.566185  2.069917
# 997  1.376983 -0.192452
# 998 -1.787214  0.694474
# 999  1.223011  1.805909
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='A',y='B',gridsize=25,cmap='coolwarm')

# %%
df.plot.kde()

# %%
df['A'].plot.kde()

# %%
df['A'].plot.density()

# %%
df1.plot.kde()
