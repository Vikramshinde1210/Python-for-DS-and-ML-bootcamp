# %%
import pandas as pd

# %%
df=pd.read_csv('E:\\ML FORUM VIIT ONLINE SESSIONS-20200717T032450Z-001\\ML FORUM VIIT ONLINE SESSIONS\\Pandas\\banklist.csv')

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...

# %%
from numpy.random import randn as rn

# %%
import numpy as np
np.random.seed(100)
df=pd.DataFrame(rn(5,4),columns=list('WXYZ'),index=list('ABCDE'))

# %%
df[['W','X']]
# Out:
#           W         X
# A -1.749765  0.342680
# B  0.981321  0.514219
# C -0.189496  0.255001
# D -0.583595  0.816847
# E -0.531280  1.029733

# %%
df['new']=df['W']+df['Z']

# %%
df
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -2.002202
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# C -0.189496  0.255001 -0.458027  0.435163  0.245668
# D -0.583595  0.816847  0.672721 -0.104411 -0.688006
# E -0.531280  1.029733 -0.438136 -1.118318 -1.649599

# %%
df.drop('A')
# Out:
#           W         X         Y         Z       new
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# C -0.189496  0.255001 -0.458027  0.435163  0.245668
# D -0.583595  0.816847  0.672721 -0.104411 -0.688006
# E -0.531280  1.029733 -0.438136 -1.118318 -1.649599

# %%
df
#axis 0 =rows
#axis 1 =columns
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -2.002202
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# C -0.189496  0.255001 -0.458027  0.435163  0.245668
# D -0.583595  0.816847  0.672721 -0.104411 -0.688006
# E -0.531280  1.029733 -0.438136 -1.118318 -1.649599

# %%
#used to access the data using labels
df.loc[['A','B']]
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -2.002202
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723

# %%
#used to access the data using index
df.iloc[0:3,:]
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -2.002202
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# C -0.189496  0.255001 -0.458027  0.435163  0.245668

# %%
df
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -2.002202
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# C -0.189496  0.255001 -0.458027  0.435163  0.245668
# D -0.583595  0.816847  0.672721 -0.104411 -0.688006
# E -0.531280  1.029733 -0.438136 -1.118318 -1.649599

# %%
df>1
# Out:
#        W      X      Y      Z    new
# A  False  False   True  False  False
# B  False  False  False  False  False
# C  False  False  False  False  False
# D  False  False  False  False  False
# E  False   True  False  False  False

# %%
df[df>1]
# Out:
#     W         X         Y   Z  new
# A NaN       NaN  1.153036 NaN  NaN
# B NaN       NaN       NaN NaN  NaN
# C NaN       NaN       NaN NaN  NaN
# D NaN       NaN       NaN NaN  NaN
# E NaN  1.029733       NaN NaN  NaN

# %%
df
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -2.002202
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# C -0.189496  0.255001 -0.458027  0.435163  0.245668
# D -0.583595  0.816847  0.672721 -0.104411 -0.688006
# E -0.531280  1.029733 -0.438136 -1.118318 -1.649599

# %%
df[df.loc[['A','B']]>0]
# Out:
#           W         X         Y   Z  new
# A       NaN  0.342680  1.153036 NaN  NaN
# B  0.981321  0.514219  0.221180 NaN  NaN
# C       NaN       NaN       NaN NaN  NaN
# D       NaN       NaN       NaN NaN  NaN
# E       NaN       NaN       NaN NaN  NaN

# %%
df
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -2.002202
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# C -0.189496  0.255001 -0.458027  0.435163  0.245668
# D -0.583595  0.816847  0.672721 -0.104411 -0.688006
# E -0.531280  1.029733 -0.438136 -1.118318 -1.649599

# %%
df[df['X']>0.5]
# Out:
#           W         X         Y         Z       new
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# D -0.583595  0.816847  0.672721 -0.104411 -0.688006
# E -0.531280  1.029733 -0.438136 -1.118318 -1.649599

# %%
df[(df['X']>0) & (df['Y']>0)]
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -2.002202
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# D -0.583595  0.816847  0.672721 -0.104411 -0.688006

# %%
df[(df['X']>0) | (df['Y']>0)]
# Out:
#           W         X         Y         Z       new
# A -1.749765  0.342680  1.153036 -0.252436 -2.002202
# B  0.981321  0.514219  0.221180 -1.070043 -0.088723
# C -0.189496  0.255001 -0.458027  0.435163  0.245668
# D -0.583595  0.816847  0.672721 -0.104411 -0.688006
# E -0.531280  1.029733 -0.438136 -1.118318 -1.649599

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z       new
# 0 -1.749765  0.342680  1.153036 -0.252436 -2.002202
# 1  0.981321  0.514219  0.221180 -1.070043 -0.088723
# 2 -0.189496  0.255001 -0.458027  0.435163  0.245668
# 3 -0.583595  0.816847  0.672721 -0.104411 -0.688006
# 4 -0.531280  1.029733 -0.438136 -1.118318 -1.649599

# %%
df.set_index('Z',inplace=True)

# %%
df
# Out:
#                   W         X         Y       new
# Z
# -0.252436 -1.749765  0.342680  1.153036 -2.002202
# -1.070043  0.981321  0.514219  0.221180 -0.088723
#  0.435163 -0.189496  0.255001 -0.458027  0.245668
# -0.104411 -0.583595  0.816847  0.672721 -0.688006
# -1.118318 -0.531280  1.029733 -0.438136 -1.649599

# %%
df.iloc[0][0]
# Out:
# -1.7497654730546974

# %%
df.index
# Out:
# Float64Index([-0.25243603652138985,  -1.0700433305682933,  0.43516348812289213,
#               -0.10441114339062771,  -1.1183182462554362],
#              dtype='float64', name='Z')

# %%
df.loc[-0.25243603652138985]
# Out:
# W     -1.749765
# X      0.342680
# Y      1.153036
# new   -2.002202
# Name: -0.25243603652138985, dtype: float64

# %%
import pandas as pd
import numpy as np
df1=pd.DataFrame({'A':[1,2,3],'B':[4,5,6],'C':[np.nan,9,np.nan]})

# %%
df1
# Out:
#    A  B    C
# 0  1  4  NaN
# 1  2  5  9.0
# 2  3  6  NaN

# %%
df1.dropna(axis=0,thresh=3)
# Out:
#    A  B    C
# 1  2  5  9.0

# %%
df1
# Out:
#    A  B    C
# 0  1  4  NaN
# 1  2  5  9.0
# 2  3  6  NaN

# %%
df1.fillna(df1['A'].mean(),inplace=True)

# %%
df1
# Out:
#    A  B    C
# 0  1  4  2.0
# 1  2  5  9.0
# 2  3  6  2.0

# %%
df.groupby('ST')

# %%
df.groupby('ST').describe()
# Out:
#     CERT                                                                    \
#    count          mean           std      min       25%      50%       75%
# ST
# AL   7.0  23105.714286   8728.675820   9609.0  18772.00  22130.0  28616.50
# AR   3.0  30681.333333  29114.327578     91.0  16996.00  33901.0  45976.50
# AZ  16.0  45201.062500  13301.805559  22314.0  34516.50  46261.5  57727.75
# CA  41.0  34795.560976  12132.859640  22574.0  27090.00  32165.0  34738.00
# CO  10.0  35057.400000  18320.310758   2994.0  23672.25  34317.0  51667.50
# CT   2.0  38112.000000  26769.648522  19183.0  28647.50  38112.0  47576.50
# FL  75.0  36146.733333  15196.798498   5672.0  26417.50  32267.0  57273.00
# GA  93.0  38180.172043  18326.224424    151.0  22238.00  35065.0  57558.00
# HI   1.0  21029.000000           NaN  21029.0  21029.00  21029.0  21029.00
# IA   2.0  20963.000000   9572.811604  14194.0  17578.50  20963.0  24347.50
# ...

# %%
# pd.concat()
# pd.merge()
df.join(df2)
