# %%
import pandas as pd

# %%
pd.Series([1,2,3,4],index=list("abcd"))
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
df=pd.read_csv('E:\\ML FORUM VIIT ONLINE SESSIONS-20200717T032450Z-001\\ML FORUM VIIT ONLINE SESSIONS\\Pandas\\banklist.csv')

# %%
df.describe().transpose()
# Out:
#       count          mean           std   min      25%      50%      75%  \
# CERT  551.0  31729.392015  16449.761311  91.0  20315.0  32218.0  35375.5
#
#           max
# CERT  58701.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...

# %%
df['Bank Name'].nunique()
# Out:
# 535

# %%
df.head(4)
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17     1-Jun-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17     1-Jun-17
# 2  58302                         Whitney Bank    28-Apr-17    23-May-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17

# %%
df.tail(3)
# Out:
#                              Bank Name        City  ST   CERT  \
# 548    First Alliance Bank & Trust Co.  Manchester  NH  34264
# 549  National State Bank of Metropolis  Metropolis  IL   3815
# 550                   Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution Closing Date Updated Date
# 548  Southern New Hampshire Bank & Trust     2-Feb-01    18-Feb-03
# 549              Banterra Bank of Marion    14-Dec-00    17-Mar-05
# 550                   Bank of the Orient    13-Oct-00    17-Mar-05

# %%
df.sample(2)
# Out:
#                   Bank Name        City  ST   CERT  \
# 421       CapitalSouth Bank  Birmingham  AL  22130
# 398  Flagship National Bank   Bradenton  FL  35044
#
#              Acquiring Institution Closing Date Updated Date
# 421                     IBERIABANK    21-Aug-09    15-Jan-13
# 398  First Federal Bank of Florida    23-Oct-09     5-Feb-15

# %%
#to get the datatypes of all the columns in Dataframe
df.dtypes
# Out:
# Bank Name                object
# City                     object
# ST                       object
# CERT                      int64
# Acquiring Institution    object
# Closing Date             object
# Updated Date             object
# dtype: object

# %%
df[['ST','CERT']]
# Out:
#      ST   CERT
# 0    IL   1802
# 1    WI  30003
# 2    LA  58302
# 3    UT  35495
# 4    IL  19328
# ..   ..    ...
# 546  IL  32646
# 547  OH   6629
# 548  NH  34264
# 549  IL   3815
# 550  HI  21029
#
# [551 rows x 2 columns]

# %%
l=[1,2,3,4,5]

# %%
enumerate(l)

# %%
#enumerate returns index of element and element also
for i,j in enumerate(l):
    print(str(i)+" "+str(j))
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %%
df.iloc([0:5])
# Out:
#   File "<ipython-input-45-847efc9f0b24>", line 1
#     df.iloc([0:5])
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# if you don't want first row as header set header = None

# %% [markdown]
# use  index_col atrribute to treat columns as indexes

# %% [markdown]
# use names attribute to pass column names
# names=[col1,col2,col3...]

# %%
pd.read_csv('E:\\ML FORUM VIIT ONLINE SESSIONS-20200717T032450Z-001\\ML FORUM VIIT ONLINE SESSIONS\\Pandas\\banklist.csv',skiprows=[0,1,2])
# Out:
#                         First NBC Bank         New Orleans  LA  58302  \
# 0                        Proficio Bank  Cottonwood Heights  UT  35495
# 1        Seaway Bank and Trust Company             Chicago  IL  19328
# 2               Harvest Community Bank          Pennsville  NJ  34951
# 3                          Allied Bank            Mulberry  AR     91
# 4         The Woodbury Banking Company            Woodbury  GA  11297
# ..                                 ...                 ...  ..    ...
# 543                 Superior Bank, FSB            Hinsdale  IL  32646
# 544                Malta National Bank               Malta  OH   6629
# 545    First Alliance Bank & Trust Co.          Manchester  NH  34264
# 546  National State Bank of Metropolis          Metropolis  IL   3815
# 547                   Bank of Honolulu            Honolulu  HI  21029
#
#                             Whitney Bank  28-Apr-17  23-May-17
# 0                      Cache Valley Bank   3-Mar-17  18-May-17
# ...

# %% [markdown]
# if you want to convert some dataset into Nan while reading data using read_csv
# na_values=[val1,val2]

# %%
pd.read_excel('C:\\Users\\vicky\\Documents\\Book1.xlsx',sheet_name='Sheet2')
# Out:
#      2
# 0    4
# 1    6
# 2    8
# 3   10
# 4   12
# 5   14
# 6   16
# 7   18
# 8   20
# 9   22
# 10  24
# 11  26
# 12  28

# %% [markdown]
# Reading data from url which contains 1 table

# %%
df2=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df2[0].to_csv('basketball.csv')

# %% [markdown]
# Reading data from url which contains multiple tables it will store each table at index in a list starting from 0

# %%
len(df2)
# Out:
# 1

# %%
df2[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df2[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df2[0].head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df2[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df2[0].index
# Out:
# RangeIndex(start=0, stop=675, step=1)

# %%
df2
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
df=pd.read_csv(r'E:\ML FORUM VIIT ONLINE SESSIONS-20200717T032450Z-001\ML FORUM VIIT ONLINE SESSIONS\Pandas\banklist.csv',chunksize=1)

# %%
df

# %%
for i in df:
    print(i)
# Out:
#              Bank Name        City  ST  CERT      Acquiring Institution  \
# 0  Fayette County Bank  Saint Elmo  IL  1802  United Fidelity Bank, fsb
#
#   Closing Date Updated Date
# 0    26-May-17     1-Jun-17
#                                            Bank Name       City  ST   CERT  \
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...  Milwaukee  WI  30003
#
#                  Acquiring Institution Closing Date Updated Date
# 1  First-Citizens Bank & Trust Company     5-May-17     1-Jun-17
#         Bank Name         City  ST   CERT Acquiring Institution Closing Date  \
# 2  First NBC Bank  New Orleans  LA  58302          Whitney Bank    28-Apr-17
#
#   Updated Date
# 2    23-May-17
#        Bank Name                City  ST   CERT Acquiring Institution  \
# 3  Proficio Bank  Cottonwood Heights  UT  35495     Cache Valley Bank
#
#   Closing Date Updated Date
# 3     3-Mar-17    18-May-17
#                        Bank Name     City  ST   CERT Acquiring Institution  \
# ...

# %%
df=pd.read_csv(r'E:\ML FORUM VIIT ONLINE SESSIONS-20200717T032450Z-001\ML FORUM VIIT ONLINE SESSIONS\Pandas\banklist.csv',nrows=10)

# %%
df.to_pickle('textpick')

# %%
pd.read_pickle('textpick')
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
import pandas as pd
df=pd.read_csv(r'E:\ML FORUM VIIT ONLINE SESSIONS-20200717T032450Z-001\ML FORUM VIIT ONLINE SESSIONS\Pandas\banklist.csv',nrows=10)

# %%
df
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
df.dtypes
# Out:
# Bank Name                object
# City                     object
# ST                       object
# CERT                      int64
# Acquiring Institution    object
# Closing Date             object
# Updated Date             object
# dtype: object

# %%
d=pd.to_datetime(df['Closing Date'])

# %%
df['new']=d

# %%
df['Closing Date']=d

# %%
df
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date  \
# ...

# %%
df.dtypes
# Out:
# Bank Name                        object
# City                             object
# ST                               object
# CERT                              int64
# Acquiring Institution            object
# Closing Date             datetime64[ns]
# Updated Date                     object
# new                      datetime64[ns]
# dtype: object

# %%
d
# Out:
# 0   2017-05-26
# 1   2017-05-05
# 2   2017-04-28
# 3   2017-03-03
# 4   2017-01-27
# 5   2017-01-13
# 6   2016-09-23
# 7   2016-08-19
# 8   2016-05-06
# 9   2016-04-29
# Name: Closing Date, dtype: datetime64[ns]

# %%
df['new']=d.dt.day

# %%
df
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date  new
# ...

# %%
df.dtypes
# Out:
# Bank Name                        object
# City                             object
# ST                               object
# CERT                              int64
# Acquiring Institution            object
# Closing Date             datetime64[ns]
# Updated Date                     object
# new                               int64
# dtype: object

# %%
d.dt.year.value_counts()
# Out:
# 2017    6
# 2016    4
# Name: Closing Date, dtype: int64

# %%
del df['new']

# %%
df
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
df.dtypes
# Out:
# Bank Name                        object
# City                             object
# ST                               object
# CERT                              int64
# Acquiring Institution            object
# Closing Date             datetime64[ns]
# Updated Date                     object
# dtype: object

# %%
i=df.dtypes[df.dtypes=='object'].index
i
# Out:
# Index(['Bank Name', 'City', 'ST', 'Acquiring Institution', 'Updated Date'], dtype='object')

# %%
df[i]
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#                  Acquiring Institution Updated Date
# 0            United Fidelity Bank, fsb     1-Jun-17
# ...

# %%
# description of columns whose datatype is object
df[i].describe()
# Out:
#                      Bank Name     City  ST  \
# count                       10       10  10
# unique                      10       10   9
# top     Harvest Community Bank  Memphis  IL
# freq                         1        1   2
#
#                       Acquiring Institution Updated Date
# count                                    10           10
# unique                                    8            5
# top     First-Citizens Bank & Trust Company     1-Jun-17
# freq                                      3            3

# %%
df
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
# first parameter is row
df.iloc[0:3,1:2]
# Out:
#           City
# 0   Saint Elmo
# 1    Milwaukee
# 2  New Orleans

# %%
df.loc[0]
# Out:
# Bank Name                      Fayette County Bank
# City                                    Saint Elmo
# ST                                              IL
# CERT                                          1802
# Acquiring Institution    United Fidelity Bank, fsb
# Closing Date                   2017-05-26 00:00:00
# Updated Date                              1-Jun-17
# Name: 0, dtype: object

# %%
df.ix[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-38d87998ad7f> in <module>
# ----> 1 df.ix[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
