# %%
import pandas as pd

# %%
import numpy as np

# %%
d=pd.date_range(start='20/5/2020',periods=7,freq='Y')

# %%
d
# Out:
# DatetimeIndex(['2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31',
#                '2024-12-31', '2025-12-31', '2026-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.Series(d)
# Out:
# 0   2020-12-31
# 1   2021-12-31
# 2   2022-12-31
# 3   2023-12-31
# 4   2024-12-31
# 5   2025-12-31
# 6   2026-12-31
# dtype: datetime64[ns]

# %%
np.arange(7.)
# Out:
# array([0., 1., 2., 3., 4., 5., 6.])

# %%
pd.Series(np.arange(7),index=d)
# Out:
# 2020-12-31    0
# 2021-12-31    1
# 2022-12-31    2
# 2023-12-31    3
# 2024-12-31    4
# 2025-12-31    5
# 2026-12-31    6
# Freq: A-DEC, dtype: int32

# %%
s[0]
# Out:
# 0

# %%
s['2022-12-31']
# Out:
# 2

# %%
import csv

# %%
f= open(r'E:\ML FORUM VIIT ONLINE SESSIONS-20200717T032450Z-001\ML FORUM VIIT ONLINE SESSIONS\Pandas\banklist.csv')

# %%
f
# Out:
# <_io.TextIOWrapper name='E:\\ML FORUM VIIT ONLINE SESSIONS-20200717T032450Z-001\\ML FORUM VIIT ONLINE SESSIONS\\Pandas\\banklist.csv' mode='r' encoding='cp1252'>

# %%
for i in f:
    print(i)
# Out:
# Bank Name,City,ST,CERT,Acquiring Institution,Closing Date,Updated Date
#
# Fayette County Bank,Saint Elmo,IL,1802,"United Fidelity Bank, fsb",26-May-17,1-Jun-17
#
# "Guaranty Bank, (d/b/a BestBank in Georgia & Michigan) ",Milwaukee,WI,30003,First-Citizens Bank & Trust Company,5-May-17,1-Jun-17
#
# First NBC Bank,New Orleans,LA,58302,Whitney Bank,28-Apr-17,23-May-17
#
# Proficio Bank,Cottonwood Heights,UT,35495,Cache Valley Bank,3-Mar-17,18-May-17
#
# Seaway Bank and Trust Company,Chicago,IL,19328,State Bank of Texas,27-Jan-17,18-May-17
#
# Harvest Community Bank,Pennsville,NJ,34951,First-Citizens Bank & Trust Company,13-Jan-17,18-May-17
#
# Allied Bank,Mulberry,AR,91,Today's Bank,23-Sep-16,17-Nov-16
#
# The Woodbury Banking Company,Woodbury,GA,11297,United Bank,19-Aug-16,1-Jun-17
#
# First CornerStone Bank,King of Prussia,PA,35312,First-Citizens Bank & Trust Company,6-May-16,6-Sep-16
#
# Trust Company Bank,Memphis,TN,9956,The Bank of Fayette County,29-Apr-16,6-Sep-16
#
# ...

# %%
c=csv.reader(f)

# %%
for i in c:
    print(i)
# Out:
# ['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution', 'Closing Date', 'Updated Date']
# ['Fayette County Bank', 'Saint Elmo', 'IL', '1802', 'United Fidelity Bank, fsb', '26-May-17', '1-Jun-17']
# ['Guaranty Bank, (d/b/a BestBank in Georgia & Michigan) ', 'Milwaukee', 'WI', '30003', 'First-Citizens Bank & Trust Company', '5-May-17', '1-Jun-17']
# ['First NBC Bank', 'New Orleans', 'LA', '58302', 'Whitney Bank', '28-Apr-17', '23-May-17']
# ['Proficio Bank', 'Cottonwood Heights', 'UT', '35495', 'Cache Valley Bank', '3-Mar-17', '18-May-17']
# ['Seaway Bank and Trust Company', 'Chicago', 'IL', '19328', 'State Bank of Texas', '27-Jan-17', '18-May-17']
# ['Harvest Community Bank', 'Pennsville', 'NJ', '34951', 'First-Citizens Bank & Trust Company', '13-Jan-17', '18-May-17']
# ['Allied Bank', 'Mulberry', 'AR', '91', "Today's Bank", '23-Sep-16', '17-Nov-16']
# ['The Woodbury Banking Company', 'Woodbury', 'GA', '11297', 'United Bank', '19-Aug-16', '1-Jun-17']
# ...

# %%
# dictionary comprehension
# {k:v for k ,v in iterator}
# use zip()
# it will try to zip data based on indexes

# %%
obj="""
{
"name":"vicky",
"age":20,
"address":[
{"permanent":"pune"},
{"local":"pune"}
]

}
"""

# %%
obj
# Out:
# '\n{\n"name":"vicky",\n"age":20,\n"address":[\n{"permanent":"pune"},\n{"local":"pune"}\n]\n\n}\n'

# %%
type(obj)
# Out:
# str

# %%
import json

# %%
j=json.loads(obj)

# %%
type(j)
# Out:
# dict

# %%
j['address']
# Out:
# [{'permanent': 'pune'}, {'local': 'pune'}]

# %%
d=pd.DataFrame(j['address'],columns=['permanent'])

# %%
d.to_json('samp.json')

# %%
pd.to_datetime
