# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)

# %%
df = np.random.randint(1,101,(100,5))

# %%
df
# Out:
# array([[ 16,  32,  24,  17,  96],
#        [ 27,  91,  16,  95,  43],
#        [ 66,  22,  35,  27,  82],
#        [ 80,  30,  64,  31,  93],
#        [ 99,  74,  43,  14,  28],
#        [ 77,   1,  86,  69,  99],
#        [ 53,  24,  15,  93,  26],
#        [ 19,  17,  63,  26,  80],
#        [ 86,  39,  66,  48,  51],
#        [ 89,  64,  88,  15,  64],
#        [ 15,  54,  69,  98,   8],
#        [ 67,  62,   3,  16,  81],
#        [ 48,  76,  86,  18,   9],
#        [ 88,  53,  16,  94,  18],
#        [ 35,  25,  24,  47,  56],
#        [ 26,  65,  91,  90,  57],
#        [ 88,  19,  33,  32,  75],
#        [ 13,  87,  17,  51, 100],
#        [ 37,  78,  91,  61,   8],
#        [ 85,  86,  78,  73,  95],
#        [ 35,   5,  38,  80,  43],
#        [ 83,  12,  32,  67,  14],
#        [ 57,  86,  67,  17,  64],
#        [ 44,  47,  51,  38,  77],
#        [ 96,  51,  54,   7,   2],
#        [ 99,  17,  36,  22,  34],
#        [ 68,  88,  45,  63,  37],
# ...

# %%
df = pd.DataFrame(np.random.randint(1,100,(100,5)),columns=[0,1,2,3,4])

# %%
df
# Out:
#      0   1   2   3   4
# 0   17  77  87  56  21
# 1   45  31  31  97  37
# 2   18  73  29  76  90
# 3   59  35  41  94  63
# 4   30  12  38  99  65
# ..  ..  ..  ..  ..  ..
# 95  24   7  25  19  38
# 96  25  81  25  26   6
# 97  68  99  79  31  37
# 98  53  17  72  85  28
# 99  40  21  46  20  15
#
# [100 rows x 5 columns]

# %%
df.columns = list("ABCDE")

# %%
df
# Out:
#      A   B   C   D   E
# 0   17  77  87  56  21
# 1   45  31  31  97  37
# 2   18  73  29  76  90
# 3   59  35  41  94  63
# 4   30  12  38  99  65
# ..  ..  ..  ..  ..  ..
# 95  24   7  25  19  38
# 96  25  81  25  26   6
# 97  68  99  79  31  37
# 98  53  17  72  85  28
# 99  40  21  46  20  15
#
# [100 rows x 5 columns]

# %%
ran = np.random.randint(0,100,200).reshape(50,4)

# %%
col = list('ABCD')

# %%
df = pd.DataFrame(data=ran,columns=col)

# %%
df
# Out:
#      A   B   C   D
# 0   25  85  62  21
# 1   77  68  19  66
# 2   70  73  49  27
# 3   35  33  42  33
# 4   93  39  64   1
# 5   58  17  59  71
# 6    1  23  80  26
# 7   37  34   3  77
# 8   20   0  62  29
# 9   47  48  89  49
# 10  17  86  47  49
# 11  63  31  35  56
# 12  83  71  72  11
# 13  26   2  16   0
# 14  50   8  79   1
# 15   1  42  28  90
# 16  35  85  23  64
# 17  20  21  43  37
# 18  89  32  66   2
# 19   2   0  90  90
# 20  56  70  53  38
# 21  89  30  20  20
# 22  46  20   9   7
# 23  66  17  65  69
# 24   7  45  18  73
# 25  29  69  91  52
# 26  91  56  49  49
# 27  42  14  21  15
# 28  33  59  10  32
# 29  89  52  28  46
# 30   9  98  71  80
# 31  89  82  81   8
# 32   7  53  64  89
# 33  23  88  18  83
# 34  67   7  57  81
# 35  94  89  95  72
# 36  80  55  55  78
# 37  87  74  70  83
# 38  89  78  65  14
# 39  36  16  97  46
# 40   2  17  23  35
# 41  81  25  18  69
# 42  21  27  63  56
# 43  20  94  54  84
# 44  67  41  65  39
# 45  79  55  33   6
# ...
