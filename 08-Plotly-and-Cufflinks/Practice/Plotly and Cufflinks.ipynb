# %%
# plotly is an interactive visualization library 
# cufflinks connects plotly with pandas
# plotly is also a company

# %%
import pandas as pd
import numpy as np

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.9.0

# %%
import cufflinks as cf

# %%
# plotly as a company supports or host online data visualization
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
# connects js to notebook by default plotly connects python and pandas
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# this allows us use cufflinks offline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4),columns=list('ABCD'))

# %%
df
# Out:
#            A         B         C         D
# 0   0.077141  0.064168 -0.827421  1.562374
# 1   0.883325 -1.079777 -0.014527  1.662962
# 2  -0.538674  1.683183 -1.230990 -1.186719
# 3   0.313894  0.360987  0.982426 -1.072296
# 4  -2.255271 -1.077513 -2.060035 -1.133884
# ..       ...       ...       ...       ...
# 95 -0.166867 -0.157319  0.551470  0.869956
# 96 -1.087901 -0.077654  0.730903  1.832795
# 97  1.135492 -0.188854 -1.998002  0.288549
# 98 -0.475855 -0.523949 -0.442011  1.129078
# 99 -0.620218  1.353257  1.418800 -0.196371
#
# [100 rows x 4 columns]

# %%
df2 = pd.DataFrame({'Category':['A','B','C' ],'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="ca7fd017-1814-40a3-9652-dbacfe3a3353" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ca7fd017-1814-40a3-9652-dbacfe3a3353")) {
#                     Plotly.newPlot(
#                         'ca7fd017-1814-40a3-9652-dbacfe3a3353',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=20)
# Out:
# <div>
#
#
#             <div id="4eae5cd0-2bcb-4e06-b218-2aee2792ca38" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4eae5cd0-2bcb-4e06-b218-2aee2792ca38")) {
#                     Plotly.newPlot(
#                         '4eae5cd0-2bcb-4e06-b218-2aee2792ca38',
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="bafa91a6-dfe4-4c1b-88ce-af79d34dcf52" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bafa91a6-dfe4-4c1b-88ce-af79d34dcf52")) {
#                     Plotly.newPlot(
#                         'bafa91a6-dfe4-4c1b-88ce-af79d34dcf52',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="676d4544-0c2e-4e92-bb18-96d01a2dbcd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("676d4544-0c2e-4e92-bb18-96d01a2dbcd6")) {
#                     Plotly.newPlot(
#                         '676d4544-0c2e-4e92-bb18-96d01a2dbcd6',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [-9.927030190782162, -10.180007997162848, 0.48277252715210683, -5.2931673808420605]}],
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="6f86589c-1984-49a5-8d8f-75251fa6866c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6f86589c-1984-49a5-8d8f-75251fa6866c")) {
#                     Plotly.newPlot(
#                         '6f86589c-1984-49a5-8d8f-75251fa6866c',
# ...

# %%
# 3D surface plot

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,20],'z':[500,400,300,200,100]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  20  100

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="12d3deba-5008-4bee-a31d-65b9f0246b12" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("12d3deba-5008-4bee-a31d-65b9f0246b12")) {
#                     Plotly.newPlot(
#                         '12d3deba-5008-4bee-a31d-65b9f0246b12',
# ...

# %%
# histogram

# %%
df["A"].iplot(kind='hist',bins=25)
# Out:
# <div>
#
#
#             <div id="a5c37801-bcbb-4417-96ca-27557ec705d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a5c37801-bcbb-4417-96ca-27557ec705d2")) {
#                     Plotly.newPlot(
#                         'a5c37801-bcbb-4417-96ca-27557ec705d2',
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="3e547b46-115c-4858-a1df-4ab3819867e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3e547b46-115c-4858-a1df-4ab3819867e1")) {
#                     Plotly.newPlot(
#                         '3e547b46-115c-4858-a1df-4ab3819867e1',
# ...

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# C:\Users\vicky\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\vicky\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="e103db73-8298-46df-8d8b-74e21affea31" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e103db73-8298-46df-8d8b-74e21affea31")) {
#                     Plotly.newPlot(
#                         'e103db73-8298-46df-8d8b-74e21affea31',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>
#
#
#             <div id="ef494ee6-e536-4818-95e5-a26a093912e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ef494ee6-e536-4818-95e5-a26a093912e8")) {
#                     Plotly.newPlot(
#                         'ef494ee6-e536-4818-95e5-a26a093912e8',
# ...

# %%
df.scatter_matrix()
# all cloumns must be numeric in order to scatter matrix to work
# Out:
# <div>
#
#
#             <div id="7b7eca87-4889-4213-8328-1501c0b47923" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7b7eca87-4889-4213-8328-1501c0b47923")) {
#                     Plotly.newPlot(
#                         '7b7eca87-4889-4213-8328-1501c0b47923',
# ...
